# %%
import pandas as pd

# %%
# List of CSV files to merge
files = ["Sales_January_2019.csv","Sales_February_2019.csv","Sales_March_2019.csv","Sales_April_2019.csv","Sales_May_2019.csv",
         "Sales_June_2019.csv","Sales_July_2019.csv","Sales_August_2019.csv",
         "Sales_September_2019.csv","Sales_October_2019.csv","Sales_November_2019.csv","Sales_December_2019.csv"]

# Read and concatenate the CSV files
df = [pd.read_csv(file) for file in files]
data = pd.concat(df, ignore_index=True)

# Write the merged DataFrame to a new CSV file
data.to_csv('merged_file.csv', index=False)

# %%
files
# Out:
# ['Sales_January_2019.csv',
#  'Sales_February_2019.csv',
#  'Sales_March_2019.csv',
#  'Sales_April_2019.csv',
#  'Sales_May_2019.csv',
#  'Sales_June_2019.csv',
#  'Sales_July_2019.csv',
#  'Sales_August_2019.csv',
#  'Sales_September_2019.csv',
#  'Sales_October_2019.csv',
#  'Sales_November_2019.csv',
#  'Sales_December_2019.csv']

# %%
data.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %%
data.head(100)
# Out:
#    Order ID                   Product Quantity Ordered Price Each  \
# 0    141234                    iPhone                1        700
# 1    141235  Lightning Charging Cable                1      14.95
# 2    141236          Wired Headphones                2      11.99
# 3    141237          27in FHD Monitor                1     149.99
# 4    141238          Wired Headphones                1      11.99
# ..      ...                       ...              ...        ...
# 95   141327      USB-C Charging Cable                1      11.95
# 96   141328           ThinkPad Laptop                1     999.99
# 97   141329      USB-C Charging Cable                1      11.95
# 98   141330          Wired Headphones                1      11.99
# 99   141331             Flatscreen TV                1        300
#
#         Order Date                          Purchase Address
# 0   01/22/19 21:25           944 Walnut St, Boston, MA 02215
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of        Order ID                     Product Quantity Ordered Price Each  \
# 0        141234                      iPhone                1        700
# 1        141235    Lightning Charging Cable                1      14.95
# 2        141236            Wired Headphones                2      11.99
# 3        141237            27in FHD Monitor                1     149.99
# 4        141238            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   319666    Lightning Charging Cable                1      14.95
# 186846   319667       AA Batteries (4-pack)                2       3.84
# 186847   319668             Vareebadd Phone                1        400
# 186848   319669            Wired Headphones                1      11.99
# 186849   319670  Bose SoundSport Headphones                1      99.99
#
#             Order Date                        Purchase Address
# ...

# %%
df1 = data[data.isna().any(axis=1)]
df1.head()
data = data.dropna(how='all')
data.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186305 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 9.9+ MB

# %%
data.value_counts()
# Out:
# Order ID  Product                   Quantity Ordered  Price Each  Order Date      Purchase Address
# Order ID  Product                   Quantity Ordered  Price Each  Order Date      Purchase Address                        355
# 158236    AA Batteries (4-pack)     1                 3.84        02/19/19 09:49  319 West St, San Francisco, CA 94016      2
# 315204    Wired Headphones          1                 11.99       12/12/19 12:41  680 6th St, San Francisco, CA 94016       2
# 256196    USB-C Charging Cable      1                 11.95       09/27/19 21:09  253 6th St, Boston, MA 02215              2
# 256763    27in FHD Monitor          1                 149.99      09/15/19 22:28  23 11th St, San Francisco, CA 94016       2
#                                                                                                                          ...
# 200687    Lightning Charging Cable  1                 14.95       05/11/19 11:31  878 7th St, Atlanta, GA 30301             1
# ...

# %%
data.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
data = data[data['Order Date'].str[0:2] != 'Or']
data.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %%
data["Month"] = data["Order Date"].str[0:2]
data['Month'] = data['Month'].astype('int32')
data.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address  Month
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215      1
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035      1
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016      1
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001      1
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301      1

# %%
data["Quantity Ordered"] = pd.to_numeric(data["Quantity Ordered"])
data["Price Each"] = pd.to_numeric(data["Price Each"])

# %%
data["Sales"] = data["Quantity Ordered"] * data["Price Each"]
data.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#        Order Date                       Purchase Address  Month   Sales
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215      1  700.00
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035      1   14.95
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016      1   23.98
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001      1  149.99
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301      1   11.99

# %%
def get_city(address):
    return address.split(',')[1]
def get_state(address):
    return address.split(',')[2].split(' ')[1]
data["City"] = data["Purchase Address"].apply(lambda x: get_city(x) + ' (' + get_state(x)+ ')')
data.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#        Order Date                       Purchase Address  Month   Sales  \
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215      1  700.00
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035      1   14.95
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016      1   23.98
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001      1  149.99
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301      1   11.99
#
#                   City
# 0          Boston (MA)
# 1        Portland (OR)
# 2   San Francisco (CA)
# 3     Los Angeles (CA)
# ...

# %%
total_sale = data.groupby("Month").sum()
total_sale
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14380\1641132983.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_sale = data.groupby("Month").sum()
#        Quantity Ordered  Price Each       Sales
# Month
# 1                 10903  1811768.38  1822256.73
# 2                 13449  2188884.72  2202022.42
# 3                 17005  2791207.83  2807100.38
# 4                 20558  3367671.02  3390670.24
# 5                 18667  3135125.13  3152606.75
# 6                 15253  2562025.61  2577802.26
# 7                 16072  2632539.56  2647775.76
# 8                 13448  2230345.42  2244467.88
# 9                 13109  2084992.09  2097560.13
# 10                22703  3715554.83  3736726.88
# 11                19798  3180600.68  3199603.20
# ...

# %%
from matplotlib import pyplot as plt 
months = range(1,13)
plt.bar(months,total_sale["Sales"])
plt.xticks(months)
plt.ylabel("Sale in USD($)")
plt.xlabel('Month')
plt.show()

# %%
total_sale = data.groupby('City').sum()
total_sale
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14380\3379471344.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_sale = data.groupby('City').sum()
#                      Quantity Ordered  Price Each   Month       Sales
# City
#  Atlanta (GA)                   16602  2779908.20  104794  2795498.58
#  Austin (TX)                    11153  1809873.61   69829  1819581.75
#  Boston (MA)                    22528  3637409.77  141112  3661642.01
#  Dallas (TX)                    16730  2752627.82  104620  2767975.40
#  Los Angeles (CA)               33289  5421435.23  208325  5452570.80
#  New York City (NY)             27932  4635370.83  175741  4664317.43
#  Portland (ME)                   2750   447189.25   17144   449758.27
# ...

# %%
cities = [city for city, df in data.groupby('City')]
plt.bar(cities,total_sale["Sales"])
plt.xticks(cities,rotation='vertical',size=7)
plt.ylabel("Sale in USD($)")
plt.xlabel('Cities')
plt.show()

# %%
data.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#        Order Date                       Purchase Address  Month   Sales  \
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215      1  700.00
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035      1   14.95
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016      1   23.98
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001      1  149.99
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301      1   11.99
#
#                   City
# 0          Boston (MA)
# 1        Portland (OR)
# 2   San Francisco (CA)
# 3     Los Angeles (CA)
# ...

# %%
data["Order Date"]=pd.to_datetime(data["Order Date"])

# %%
data.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#            Order Date                       Purchase Address  Month   Sales  \
# 0 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215      1  700.00
# 1 2019-01-28 14:15:00       185 Maple St, Portland, OR 97035      1   14.95
# 2 2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016      1   23.98
# 3 2019-01-05 20:33:00     738 10th St, Los Angeles, CA 90001      1  149.99
# 4 2019-01-25 11:59:00          387 10th St, Austin, TX 73301      1   11.99
#
#                   City
# 0          Boston (MA)
# 1        Portland (OR)
# 2   San Francisco (CA)
# ...

# %%
data['Hour'] = data['Order Date'].dt.hour
data["Count"]=1
data.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#            Order Date                       Purchase Address  Month   Sales  \
# 0 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215      1  700.00
# 1 2019-01-28 14:15:00       185 Maple St, Portland, OR 97035      1   14.95
# 2 2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016      1   23.98
# 3 2019-01-05 20:33:00     738 10th St, Los Angeles, CA 90001      1  149.99
# 4 2019-01-25 11:59:00          387 10th St, Austin, TX 73301      1   11.99
#
#                   City  Hour  Count
# 0          Boston (MA)    21      1
# ...

# %%
hour = [hour for hour, df in data.groupby('Hour')]
plt.plot(hour,data.groupby(['Hour']).count())
plt.xticks(hour)
plt.xlabel('Hours')
plt.ylabel('Number of orders')
plt.grid()
plt.show()

# %%
data.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#            Order Date                       Purchase Address  Month   Sales  \
# 0 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215      1  700.00
# 1 2019-01-28 14:15:00       185 Maple St, Portland, OR 97035      1   14.95
# 2 2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016      1   23.98
# 3 2019-01-05 20:33:00     738 10th St, Los Angeles, CA 90001      1  149.99
# 4 2019-01-25 11:59:00          387 10th St, Austin, TX 73301      1   11.99
#
#                   City  Hour  Count
# 0          Boston (MA)    21      1
# ...

# %%
df = data[data['Order ID'].duplicated(keep=False)]
df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
df = df[['Order ID','Grouped']].drop_duplicates()
df.head()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14380\929912927.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
#     Order ID                                         Grouped
# 41    141275           USB-C Charging Cable,Wired Headphones
# 57    141290  Apple Airpods Headphones,AA Batteries (4-pack)
# 133   141365                Vareebadd Phone,Wired Headphones
# 153   141384               Google Phone,USB-C Charging Cable
# 220   141450         Google Phone,Bose SoundSport Headphones

# %%
from itertools import combinations
from collections import Counter
count = Counter()
for row in df['Grouped']:
    rowlist = row.split(',')
    count.update(Counter(combinations(rowlist,2)))
    
for key, value in count.most_common(10):
    print(key,value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %%
product_grouped = data.groupby('Product')
quantity_ordered = product_grouped.sum()['Quantity Ordered']

products = [product for product,df in product_grouped]
plt.bar(products,quantity_ordered)
plt.ylabel('Quantity Ordered')
plt.xlabel('Products')
plt.xticks(products,rotation='vertical',size=7)
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14380\131683737.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   quantity_ordered = product_grouped.sum()['Quantity Ordered']

# %%
price = data.groupby('Product').mean()['Price Each']


fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(products,quantity_ordered,color='g')
ax2.plot(products, price, 'b-')

ax1.set_xlabel('Products Name')
ax1.set_ylabel('Quantity Ordered', color='g')
ax2.set_ylabel('Price ($)', color='b')
ax1.set_xticklabels(products,rotation='vertical',size=7)
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14380\126088575.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   price = data.groupby('Product').mean()['Price Each']
# C:\Users\hp\AppData\Local\Temp\ipykernel_14380\126088575.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(products,rotation='vertical',size=7)

# %%
import seaborn as sns

# %%
data.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address', 'Month', 'Sales', 'City', 'Hour', 'Count'],
#       dtype='object')

# %%
sns.histplot(x=data["Quantity Ordered"])
# Out:
# <Axes: xlabel='Quantity Ordered', ylabel='Count'>

# %%
sns.set(rc={'figure.figsize':(49,20)})
sns.histplot(x=data["Product"],kde=True)
# Out:
# <Axes: xlabel='Product', ylabel='Count'>

# %%
sns.set(rc={'figure.figsize':(8,4)})
sns.histplot(x=data["Sales"])
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>
